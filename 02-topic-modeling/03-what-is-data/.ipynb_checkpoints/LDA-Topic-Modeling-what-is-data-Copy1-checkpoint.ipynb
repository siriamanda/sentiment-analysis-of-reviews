# %%
# Import the libraries

import pandas as pd 
import numpy as np

from pprint import pprint

# libraries for visualization
import pyLDAvis
import pyLDAvis.gensim
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import re

import spacy

import gensim
from gensim import corpora, models
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

import nltk
from nltk import FreqDist
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.tag import pos_tag, pos_tag_sents
from nltk.corpus import wordnet

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Code references:
#
# https://www.analyticsvidhya.com/blog/2018/10/mining-online-reviews-topic-modeling-lda/

# %%
df = pd.read_csv('/Users/siriamanda/Desktop/LNU-VT-2021/Thesis/11-data-analysis/sentiment-analysis-of-reviews/01-sentiment-analysis/03-what-is-data/VADER-what-is-data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0        date                                             review  \
# 0           0  2021-03-11  This course has a good overview of data scienc...
# 1           1  2021-03-11                                      Greate Course
# 2           2  2021-03-10  have an overall understanding of data science ...
# 3           3  2021-03-10        Course creates interest to keep on learning
# 4           4  2021-03-10  Even though I have been self-teaching for abou...
#
#    rating     status  length label  \
# 0       5  completer     371   pos
# 1       5  completer      13   pos
# 2       5  completer      70   pos
# 3       4  completer      43   pos
# 4       5  completer     148   pos
#
#                                    language_scores language  \
# 0  {'language': 'en', 'score': 0.9999957253533018}       en
# 1   {'language': 'en', 'score': 0.999994475073214}       en
# 2  {'language': 'en', 'score': 0.9999964991174284}       en
# 3  {'language': 'en', 'score': 0.9999949953681738}       en
# 4  {'language': 'en', 'score': 0.9999963070938086}       en
#
#                                               scores  compound sentiment
# 0  {'neg': 0.0, 'neu': 0.803, 'pos': 0.197, 'comp...    0.8999       pos
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000       neu
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000       neu
# 3  {'neg': 0.0, 'neu': 0.495, 'pos': 0.505, 'comp...    0.6249       pos
# 4  {'neg': 0.0, 'neu': 0.921, 'pos': 0.079, 'comp...    0.2263       pos

# %%
df.drop(['Unnamed: 0', 'language_scores', 'language', 'scores'], axis = 1, inplace = True)

# %%
df
# Out:
#             date                                             review  rating  \
# 0     2021-03-11  This course has a good overview of data scienc...       5
# 1     2021-03-11                                      Greate Course       5
# 2     2021-03-10  have an overall understanding of data science ...       5
# 3     2021-03-10        Course creates interest to keep on learning       4
# 4     2021-03-10  Even though I have been self-teaching for abou...       5
# ...          ...                                                ...     ...
# 7869  2018-08-28         Thanks for the data science introduction!        5
# 7870  2018-08-28  Some very interesting materials in the form of...       5
# 7871  2018-08-28  Very easy to understand. A perfect introductio...       5
# 7872  2018-08-25  Was good learning spl, if you are looking to b...       5
# 7873  2018-08-24  Good for getting information about Data scienc...       5
#
#          status  length label  compound sentiment
# 0     completer     371   pos    0.8999       pos
# 1     completer      13   pos    0.0000       neu
# 2     completer      70   pos    0.0000       neu
# 3     completer      43   pos    0.6249       pos
# 4     completer     148   pos    0.2263       pos
# ...         ...     ...   ...       ...       ...
# 7869    dropout      42   pos    0.4926       pos
# 7870    dropout      72   pos    0.6240       pos
# 7871    dropout     104   pos    0.8655       pos
# 7872  completer      96   pos    0.4404       pos
# 7873    dropout      90   pos    0.4404       pos
#
# [7874 rows x 8 columns]

# %%
# Check for null values

len(df[df['review'].isna()==True])
# Out:
# 0

# %%
# Drop null values

# df.dropna(inplace = True)

# %%
# Check for null values

# len(df[df['review'].isna()==True])

# %%
# Reset the index

# df = df.reset_index(drop = True)

# %%
# df

# %%
# Define a function to plot the most frequent words

def freq_words(x, terms = 30):
    all_words = ' '.join([text for text in x])
    all_words = all_words.split()

    fdist = FreqDist(all_words)
    words_df = pd.DataFrame({'word':list(fdist.keys()), 'count':list(fdist.values())})
    
    # selecting top 20 most frequent words
    d = words_df.nlargest(columns="count", n = terms) 
    plt.figure(figsize=(20,5))
    ax = sns.barplot(data=d, x= "word", y = "count")
    ax.set(ylabel = 'Count')
    plt.xticks(rotation = 45)
    plt.show()

# %%
# The most frquent words are stop words such as 'to' and 'the' we will remove these in the preprocessing steps

freq_words(df['review'])

# %% [markdown]
# ## Preprocessing

# %%
# Covert to lowercase

df['preprocessed'] =  df['review'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df['preprocessed'].head()
# Out:
# 0    this course has a good overview of data scienc...
# 1                                        greate course
# 2    have an overall understanding of data science ...
# 3          course creates interest to keep on learning
# 4    even though i have been self-teaching for abou...
# Name: preprocessed, dtype: object

# %%
# Remove punctuations

df['preprocessed'] = df['preprocessed'].str.replace('[^\w\s]','')
df['preprocessed'].head()
# Out:
# 0    this course has a good overview of data scienc...
# 1                                        greate course
# 2    have an overall understanding of data science ...
# 3          course creates interest to keep on learning
# 4    even though i have been selfteaching for about...
# Name: preprocessed, dtype: object

# %%
# Remove stopwords

stop = stopwords.words('english')
stop.extend(['good', 'great', 'really', 'like', 'nice', 'one', 'would', 'could'])

df['preprocessed'] = df['preprocessed'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df['preprocessed'].head()
# Out:
# 0    course overview data science related concepts ...
# 1                                        greate course
# 2      overall understanding data science future looks
# 3                course creates interest keep learning
# 4    even though selfteaching year surprised much l...
# Name: preprocessed, dtype: object

# %%
df[(df['preprocessed']== "")]
# Out:
#             date     review  rating     status  length label  compound  \
# 19    2021-03-05       nice       5  completer       4   pos    0.4215
# 21    2021-03-05       good       5  completer       4   pos    0.4404
# 23    2021-03-05  Very good       5  completer       9   pos    0.4927
# 83    2021-02-22      Good        5  completer       5   pos    0.4404
# 130   2021-02-13     great!       5  completer       6   pos    0.6588
# ...          ...        ...     ...        ...     ...   ...       ...
# 7449  2018-12-08  Very good       5  completer       9   pos    0.4927
# 7497  2018-11-20       nice       5    dropout       4   pos    0.4215
# 7508  2018-11-17       good       4  completer       4   pos    0.4404
# 7546  2018-11-07       Nice       5  completer       4   pos    0.4215
# 7617  2018-10-21  For what?       1    dropout       9   neg    0.0000
#
#      sentiment preprocessed
# 19         pos
# 21         pos
# 23         pos
# 83         pos
# 130        pos
# ...        ...          ...
# 7449       pos
# 7497       pos
# 7508       pos
# 7546       pos
# 7617       neu
#
# [233 rows x 9 columns]

# %%
df = df[(df['preprocessed']!= "")]

# %%
# Reset the index

df = df.reset_index(drop = True)

# %%
# Remove short words (length < 3)

# df['review'] = df['review'].apply(lambda x: ' '.join([w for w in x.split() if len(w)>2]))
# df['review'].head()

# %%
# Look at the most frequent words again 

freq_words(df['preprocessed'])

# %%
# Tokenization

tokenizer = RegexpTokenizer(r'\w+')

df['preprocessed'] = df['preprocessed'].apply(lambda x: tokenizer.tokenize(x.lower()))
df['preprocessed'].head(5)
# Out:
# 0    [course, overview, data, science, related, con...
# 1                                     [greate, course]
# 2    [overall, understanding, data, science, future...
# 3          [course, creates, interest, keep, learning]
# 4    [even, though, selfteaching, year, surprised, ...
# Name: preprocessed, dtype: object

# %%
# Add speech tags

df['preprocessed'] = df['preprocessed'].apply(nltk.tag.pos_tag)
df['preprocessed'].head()
# Out:
# 0    [(course, NN), (overview, NN), (data, NNS), (s...
# 1                         [(greate, NN), (course, NN)]
# 2    [(overall, JJ), (understanding, NN), (data, NN...
# 3    [(course, NN), (creates, VBZ), (interest, NN),...
# 4    [(even, RB), (though, IN), (selfteaching, VBG)...
# Name: preprocessed, dtype: object

# %%
# Define function to convert parts of speech tags to wordnet’s format

def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
# Apply the function to the tagged data

df['preprocessed'] = df['preprocessed'].apply(lambda x: [(word, get_wordnet_pos(pos_tag)) for (word, pos_tag) in x])
df['preprocessed'].head()
# Out:
# 0    [(course, n), (overview, n), (data, n), (scien...
# 1                           [(greate, n), (course, n)]
# 2    [(overall, a), (understanding, n), (data, n), ...
# 3    [(course, n), (creates, v), (interest, n), (ke...
# 4    [(even, r), (though, n), (selfteaching, v), (y...
# Name: preprocessed, dtype: object

# %%
# Create lemmatizer

lemmatizer = WordNetLemmatizer()

# Apply to data 

df['preprocessed'] = df['preprocessed'].apply(lambda x: [lemmatizer.lemmatize(word, tag) for word, tag in x])
df['preprocessed'].head()
# Out:
# 0    [course, overview, data, science, relate, conc...
# 1                                     [greate, course]
# 2    [overall, understanding, data, science, future...
# 3           [course, create, interest, keep, learning]
# 4    [even, though, selfteaching, year, surprise, m...
# Name: preprocessed, dtype: object

# %%
# Join reviews

df['joined'] = df['preprocessed'].apply(lambda x: ' '.join(x))

# %%
# Most frequent words after lemmatizing 

freq_words(df['joined'], 35)

# %% [markdown]
# ## LDA Topic Modeling

# %%
# Create a dictionary from 'df_sen['review']' containing the number of times a word appears in the training set

dictionary = gensim.corpora.Dictionary(df['preprocessed'])

# %%
# Gensim filter extremes

# Filter out tokens that appear in:
# Less than 50 documents, more than 0.5 documents, and keep only 100000 most frquent tokens

# dictionary.filter_extremes(no_below = 50, no_above = 0.5, keep_n = 100000)

# %%
# Gensim doc2bow
# Create a dictionary reporting how many words and how many times those words appear

corpus = [dictionary.doc2bow(doc) for doc in df['preprocessed']]

# %%
# Add TF-IDF

tfidf = models.TfidfModel(corpus)      # Create a TF-IDF model
corpus_tfidf = tfidf[corpus]

# %%
# Creating the object for LDA model using gensim library
LDA = gensim.models.LdaMulticore

# Build LDA model
lda_model = LDA(corpus = corpus, id2word = dictionary, num_topics = 3, random_state = 100,
                chunksize = 100, passes = 10, alpha = 0.25)

# %%
# Explore the words occurring in each topic and its relative weight

for id, topic in lda_model.print_topics(-1):
    print('Topic: {}\nWord: {}\n'.format(id, topic))
    
print('Topic 0: Technologies or course delivery, Topic 1: Content, Topic 2: Learner experience')
# Out:
# Topic: 0
# Word: 0.037*"course" + 0.015*"video" + 0.010*"informative" + 0.009*"learn" + 0.009*"material" + 0.008*"content" + 0.007*"time" + 0.007*"much" + 0.007*"videos" + 0.007*"read"
#
# Topic: 1
# Word: 0.143*"data" + 0.115*"science" + 0.063*"course" + 0.031*"introduction" + 0.020*"scientist" + 0.015*"basic" + 0.014*"give" + 0.014*"field" + 0.013*"start" + 0.013*"learn"
#
# Topic: 2
# Word: 0.101*"course" + 0.042*"excellent" + 0.028*"easy" + 0.024*"well" + 0.018*"content" + 0.017*"learn" + 0.016*"coursera" + 0.015*"beginner" + 0.015*"thanks" + 0.015*"thank"
#
# Topic 0: Technologies or course delivery, Topic 1: Content, Topic 2: Learner experience

# %% [markdown]
# ### Visualise with pyLDAvis
#
# Original paper: https://nlp.stanford.edu/events/illvi2014/papers/sievert-illvi2014.pdf

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 1      0.203255  0.061077       1        1  51.237434
# 0     -0.041522 -0.185443       2        1  31.462873
# 2     -0.161733  0.124366       3        1  17.299693, topic_info=             Term         Freq        Total Category  logprob  loglift
# 8            data  4894.000000  4894.000000  Default  30.0000  30.0000
# 21        science  3912.000000  3912.000000  Default  29.0000  29.0000
# 7          course  4066.000000  4066.000000  Default  28.0000  28.0000
# 55      excellent   539.000000   539.000000  Default  27.0000  27.0000
# 118          easy   328.000000   328.000000  Default  26.0000  26.0000
# ..            ...          ...          ...      ...      ...      ...
# 139      material    79.081576   261.493241   Topic3  -4.9751   0.5586
# 34           much    71.582676   258.173897   Topic3  -5.0747   0.4717
# 109         clear    66.881759   233.600473   Topic3  -5.1427   0.5038
# 64           make    62.871521   250.574517   Topic3  -5.2045   0.3718
# 97   introductory    63.700103   406.856331   Topic3  -5.1914  -0.0998
#
# [207 rows x 6 columns], token_table=      Topic      Freq       Term
# term
# 387       2  0.980826          2
# 254       2  0.991991          3
# 982       1  0.975083   absolute
# 180       2  0.969682        add
# 180       3  0.020202        add
# ...     ...       ...        ...
# 449       2  0.013113  wonderful
# 449       3  0.681853  wonderful
# 79        1  0.991876      world
# 79        3  0.005304      world
# 2063      3  0.978631          ã
#
# [314 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 1, 3])

# %% [markdown]
# What is topic perplexity and topic coherence: https://towardsdatascience.com/evaluate-topic-model-in-python-latent-dirichlet-allocation-lda-7d57484bb5d0

# %%
# Calculate Perplexity and Coherence

# Compute Perplexity

print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. The lower the better.

# Compute Coherence Score

coherence_model_lda = CoherenceModel(model = lda_model, texts = df['preprocessed'], dictionary = dictionary, coherence = 'c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Perplexity:  -6.234327797601864
#
# Coherence Score:  0.4742334030373087

# %% [markdown]
# ## Hyperparameter Tuning
#
# Code references
#
# Find the optimal number of topics, alpha and beta: https://towardsdatascience.com/evaluate-topic-model-in-python-latent-dirichlet-allocation-lda-7d57484bb5d0
#
# What is alpha and beta: https://www.thoughtvector.io/blog/lda-alpha-and-beta-parameters-the-intuition/

# %% [markdown]
# ## Calculate the coherence score
#
# Code reference:
#
# https://www.machinelearningplus.com/nlp/topic-modeling-gensim-python/#17howtofindtheoptimalnumberoftopicsforlda

# %%
# Determine the optiomal number of topics by calculating the coherence score

# Define function for calculating coherence score

def compute_coherence_values(dictionary, corpus, texts, limit, start = 2, step = 3):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = LDA(corpus = corpus, num_topics = num_topics, id2word = dictionary, random_state = 100,
                chunksize = 100, passes = 10)
        model_list.append(model)
        coherencemodel = CoherenceModel(model = model, texts = texts, dictionary = dictionary, coherence = 'c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values

# %%
# Can take a long time to run.

model_list, coherence_values = compute_coherence_values(dictionary = dictionary, corpus = corpus, texts = df['preprocessed'], start = 2, limit = 10, step = 1)

# %%
# Show graph

limit = 10; start = 2; step = 1;
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc = 'best')
plt.show()

# %%
# Print the coherence scores

for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4))
# Out:
# Num Topics = 2  has Coherence Value of 0.4655
# Num Topics = 3  has Coherence Value of 0.4718
# Num Topics = 4  has Coherence Value of 0.4499
# Num Topics = 5  has Coherence Value of 0.4629
# Num Topics = 6  has Coherence Value of 0.4088
# Num Topics = 7  has Coherence Value of 0.4076
# Num Topics = 8  has Coherence Value of 0.4016
# Num Topics = 9  has Coherence Value of 0.388

# %% [markdown]
# ## LDA Mallet Model
#
# Code reference:
#
# https://www.machinelearningplus.com/nlp/topic-modeling-gensim-python/#17howtofindtheoptimalnumberoftopicsforlda

# %%
mallet_path = '/Users/siriamanda/Desktop/LNU-VT-2021/Thesis/11-data-analysis/mallet-2.0.8/bin/mallet' # update this path
ldamallet = gensim.models.wrappers.LdaMallet(mallet_path, corpus = corpus, num_topics = 5, id2word = dictionary)

# %%
# Show Topics
pprint(ldamallet.show_topics(formatted = False))

# Compute Coherence Score
coherence_model_ldamallet = CoherenceModel(model = ldamallet, texts = df['preprocessed'], dictionary = dictionary, coherence = 'c_v')
coherence_ldamallet = coherence_model_ldamallet.get_coherence()
print('\nCoherence Score: ', coherence_ldamallet)

# The coherence score using the Mallet Model is lower than the original LDA Model
# Out:
# [(0,
#   [('video', 0.029447059909535677),
#    ('material', 0.025385396473737654),
#    ('information', 0.022062217298993814),
#    ('people', 0.020677559309517216),
#    ('complete', 0.01689282747161451),
#    ('time', 0.015600480014769685),
#    ('student', 0.01375426936213422),
#    ('read', 0.013292716698975353),
#    ('question', 0.011908058709498754),
#    ('quiz', 0.011077263915812794)]),
#  (1,
#   [('science', 0.1557513460597161),
#    ('data', 0.12765540871267744),
#    ('introduction', 0.0990699951052374),
#    ('excellent', 0.059520313264806654),
#    ('understand', 0.058541360744003915),
#    ('basic', 0.05824767498776309),
#    ('field', 0.052276064610866375),
#    ('beginner', 0.04522760646108664),
#    ('helpful', 0.024963289280469897),
#    ('explain', 0.023299069995105236)]),
#  (2,
#   [('science', 0.11956413076077177),
#    ('data', 0.08987303808857343),
#    ('start', 0.05358392482255323),
#    ('introductory', 0.03958812356293112),
#    ('knowledge', 0.034089773068079574),
#    ('coursera', 0.028791362591222634),
#    ('experience', 0.02839148255523343),
#    ('ibm', 0.02579226232130361),
#    ('career', 0.023992802159352195),
#    ('world', 0.01969409177246826)]),
#  (3,
#   [('data', 0.2948816624975948),
#    ('science', 0.13575139503559747),
#    ('scientist', 0.07148354820088512),
#    ('give', 0.04791225707138734),
#    ('provide', 0.02924764287088705),
#    ('overview', 0.02588031556667308),
#    ('clear', 0.02414854723879161),
#    ('insight', 0.01885703290359823),
#    ('skill', 0.015008658841639407),
#    ('introduction', 0.013950355974600731)]),
#  (4,
#   [('learn', 0.07677677677677677),
#    ('easy', 0.035735735735735734),
#    ('content', 0.03313313313313313),
#    ('informative', 0.03283283283283283),
#    ('lot', 0.02962962962962963),
#    ('make', 0.02832832832832833),
#    ('interest', 0.019119119119119118),
#    ('awesome', 0.018018018018018018),
#    ('topic', 0.017717717717717716),
#    ('intro', 0.016416416416416415)])]
#
# Coherence Score:  0.42327154926745286

# %%
# Create new column with the topic

df['topic'] = ''

df['topic'] = [max(p, key = lambda item: item[1]) for p in lda_model[corpus]]

# %%
# Create two separate columns for the topic ID and topic score

df[['topic_id', 'topic_score']] = df['topic'].apply(pd.Series)

# %%
df
# Out:
#             date                                             review  rating  \
# 0     2021-03-11  This course has a good overview of data scienc...       5
# 1     2021-03-11                                      Greate Course       5
# 2     2021-03-10  have an overall understanding of data science ...       5
# 3     2021-03-10        Course creates interest to keep on learning       4
# 4     2021-03-10  Even though I have been self-teaching for abou...       5
# ...          ...                                                ...     ...
# 7636  2018-08-28         Thanks for the data science introduction!        5
# 7637  2018-08-28  Some very interesting materials in the form of...       5
# 7638  2018-08-28  Very easy to understand. A perfect introductio...       5
# 7639  2018-08-25  Was good learning spl, if you are looking to b...       5
# 7640  2018-08-24  Good for getting information about Data scienc...       5
#
#          status  length label  compound sentiment  \
# 0     completer     371   pos    0.8999       pos
# 1     completer      13   pos    0.0000       neu
# 2     completer      70   pos    0.0000       neu
# 3     completer      43   pos    0.6249       pos
# 4     completer     148   pos    0.2263       pos
# ...         ...     ...   ...       ...       ...
# 7636    dropout      42   pos    0.4926       pos
# 7637    dropout      72   pos    0.6240       pos
# 7638    dropout     104   pos    0.8655       pos
# 7639  completer      96   pos    0.4404       pos
# 7640    dropout      90   pos    0.4404       pos
#
#                                            preprocessed  \
# 0     [course, overview, data, science, relate, conc...
# 1                                      [greate, course]
# 2     [overall, understanding, data, science, future...
# 3            [course, create, interest, keep, learning]
# 4     [even, though, selfteaching, year, surprise, m...
# ...                                                 ...
# 7636              [thanks, data, science, introduction]
# 7637  [interesting, material, form, well, puttogethe...
# 7638  [easy, understand, perfect, introduction, data...
# 7639  [learn, spl, look, build, anlaytics, skill, da...
# 7640     [get, information, data, science, check, need]
#
#                                                  joined            topic  \
# 0     course overview data science relate concept al...   (1, 0.8647405)
# 1                                         greate course   (2, 0.8143114)
# 2        overall understanding data science future look  (1, 0.92023826)
# 3                  course create interest keep learning  (0, 0.90366244)
# 4     even though selfteaching year surprise much le...   (0, 0.6859359)
# ...                                                 ...              ...
# 7636                   thanks data science introduction   (1, 0.7201225)
# 7637   interesting material form well puttogether video  (0, 0.67606914)
# 7638  easy understand perfect introduction data scie...  (2, 0.57855624)
# 7639  learn spl look build anlaytics skill data science   (1, 0.9405767)
# 7640            get information data science check need  (1, 0.71219456)
#
#       topic_id  topic_score
# 0          1.0     0.864740
# 1          2.0     0.814311
# 2          1.0     0.920238
# 3          0.0     0.903662
# 4          0.0     0.685936
# ...        ...          ...
# 7636       1.0     0.720123
# 7637       0.0     0.676069
# 7638       2.0     0.578556
# 7639       1.0     0.940577
# 7640       1.0     0.712195
#
# [7641 rows x 13 columns]

# %%
df_final = df.drop(['joined', 'topic'], axis = 1)

# %%
# Save dataframe as a csv file

df_final.to_csv('what-is-data-final.csv')

# %%
df_final.head(31)
# Out:
#           date                                             review  rating  \
# 0   2021-03-11  This course has a good overview of data scienc...       5
# 1   2021-03-11                                      Greate Course       5
# 2   2021-03-10  have an overall understanding of data science ...       5
# 3   2021-03-10        Course creates interest to keep on learning       4
# 4   2021-03-10  Even though I have been self-teaching for abou...       5
# 5   2021-03-10                                         Good intro       5
# 6   2021-03-09                                  Good introduction       4
# 7   2021-03-09     The explanation is awesome with a rich content       4
# 8   2021-03-09  I finally got answers to some of my questions ...       5
# 9   2021-03-09                                         Excellent!       5
# 10  2021-03-09                Very basic and sometimes confusing        3
# 11  2021-03-08  I have a great understanding of the role of th...       5
# 12  2021-03-07  Great course to get introduced to the sexiest ...       5
# 13  2021-03-07  Thanks for the course. Now I know what are the...       5
# 14  2021-03-07                                   very nice course       5
# 15  2021-03-07  This course helps me to gain knowledge about w...       5
# 16  2021-03-06   Best Course for Beginners in Data Science Field.       5
# 17  2021-03-06  Thanks to IBM and Coursera.this is really a gr...       4
# 18  2021-03-05                                        Nice course       5
# 19  2021-03-05  This course was good introduction. However, th...       4
# 20  2021-03-05   Great course to start your Data Science Learning       5
# 21  2021-03-05                        insightful and enlightening       5
# 22  2021-03-05  the  course covers basic concept of Data Scien...       5
# 23  2021-03-04  Introduction to data science and the job of da...       4
# 24  2021-03-04                                           payment        1
# 25  2021-03-04  This course defines a data and data scientist ...       5
# 26  2021-03-04  It is made easy to listen and learn. Perfect l...       5
# 27  2021-03-04  Best course for understanding base of the data...       5
# 28  2021-03-04  amazing course for understanding the term data...       5
# 29  2021-03-03  It was a well structured intro to data science :)       5
# 30  2021-03-03  An interesting and gentle introduction to basi...       4
#
#        status  length label  compound sentiment  \
# 0   completer     371   pos    0.8999       pos
# 1   completer      13   pos    0.0000       neu
# 2   completer      70   pos    0.0000       neu
# 3   completer      43   pos    0.6249       pos
# 4   completer     148   pos    0.2263       pos
# 5   completer      10   pos    0.4404       pos
# 6   completer      17   pos    0.4404       pos
# 7   completer      46   pos    0.8271       pos
# 8   completer     269   pos    0.8899       pos
# 9   completer      10   pos    0.6114       pos
# 10  completer      35   neu   -0.2263       neg
# 11  completer     414   pos    0.9273       pos
# 12  completer      82   pos    0.6249       pos
# 13  completer      98   pos    0.4404       pos
# 14  completer      16   pos    0.4754       pos
# 15  completer      76   pos    0.7184       pos
# 16  completer      48   pos    0.6369       pos
# 17  completer      70   pos    0.8070       pos
# 18  completer      11   pos    0.4215       pos
# 19  completer     106   pos    0.4404       pos
# 20  completer      48   pos    0.6249       pos
# 21  completer      27   pos    0.5106       pos
# 22  completer     130   pos    0.5413       pos
# 23  completer      70   pos    0.1027       pos
# 24  completer       8   neg    0.0000       neu
# 25  completer     112   pos    0.0000       neu
# 26  completer      62   pos    0.7840       pos
# 27  completer      54   pos    0.6369       pos
# 28  completer      64   pos    0.5859       pos
# 29  completer      49   pos    0.6249       pos
# 30  completer      72   pos    0.6808       pos
#
#                                          preprocessed  topic_id  topic_score
# 0   [course, overview, data, science, relate, conc...       1.0     0.864740
# 1                                    [greate, course]       2.0     0.814311
# 2   [overall, understanding, data, science, future...       1.0     0.920238
# 3          [course, create, interest, keep, learning]       0.0     0.903662
# 4   [even, though, selfteaching, year, surprise, m...       0.0     0.685936
# 5                                             [intro]       1.0     0.710387
# 6                                      [introduction]       1.0     0.712316
# 7               [explanation, awesome, rich, content]       2.0     0.893560
# 8   [finally, get, answer, question, relate, data,...       0.0     0.514934
# 9                                         [excellent]       2.0     0.713893
# 10                        [basic, sometimes, confuse]       0.0     0.632443
# 11  [understanding, role, data, scientist, objecti...       1.0     0.651099
# 12  [course, get, introduce, sexy, job, 21st, cent...       1.0     0.517461
# 13  [thanks, course, know, competence, need, becom...       1.0     0.849121
# 14                                           [course]       2.0     0.701463
# 15  [course, help, gain, knowledge, whats, data, s...       1.0     0.942037
# 16     [best, course, beginner, data, science, field]       1.0     0.922055
# 17  [thanks, ibm, courserathis, introductory, course]       2.0     0.910546
# 18                                           [course]       2.0     0.701382
# 19  [course, introduction, however, test, less, me...       0.0     0.514139
# 20           [course, start, data, science, learning]       1.0     0.909913
# 21                            [insightful, enlighten]       2.0     0.814451
# 22  [course, cover, basic, concept, data, science,...       1.0     0.962857
# 23  [introduction, data, science, job, data, scien...       1.0     0.934586
# 24                                          [payment]       2.0     0.713447
# 25  [course, defines, data, data, scientist, along...       1.0     0.822565
# 26  [make, easy, listen, learn, perfect, lecture, ...       2.0     0.931877
# 27  [best, course, understanding, base, data, scie...       1.0     0.922888
# 28  [amaze, course, understanding, term, data, sci...       1.0     0.933559
# 29            [well, structure, intro, data, science]       1.0     0.579838
# 30  [interesting, gentle, introduction, basic, con...       1.0     0.933813
