# %%
# Import the libraries

import pandas as pd 
import numpy as np

from pprint import pprint

# libraries for visualization
import pyLDAvis
import pyLDAvis.gensim
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import re

import spacy

import gensim
from gensim import corpora, models
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

import nltk
from nltk import FreqDist
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.tag import pos_tag, pos_tag_sents
from nltk.corpus import wordnet

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Code references:
#
# https://www.analyticsvidhya.com/blog/2018/10/mining-online-reviews-topic-modeling-lda/

# %%
df = pd.read_csv('/Users/siriamanda/Desktop/LNU-VT-2021/Thesis/11-data-analysis/sentiment-analysis-of-reviews/01-sentiment-analysis/05-python-for-data/VADER-python-for-data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0        date                                             review  \
# 0           0  2021-03-11  Interesting and clear, the difficulty in the e...
# 1           1  2021-03-11  great, i have learned basics of python from th...
# 2           2  2021-03-10                                        Recommended
# 3           3  2021-03-10                                          excellent
# 4           4  2021-03-10  Tamada sir is my biggest inspiration to comple...
#
#    rating     status  length label  \
# 0       4  completer     186   pos
# 1       5  completer      56   pos
# 2       5  completer      11   pos
# 3       5  completer       9   pos
# 4       5  completer     102   pos
#
#                                    language_scores language  \
# 0  {'language': 'en', 'score': 0.9999988844000527}       en
# 1  {'language': 'en', 'score': 0.9999970049413354}       en
# 2  {'language': 'en', 'score': 0.8571409981818681}       en
# 3  {'language': 'ca', 'score': 0.8571389147750391}       ca
# 4  {'language': 'en', 'score': 0.9999982800455944}       en
#
#                                               scores  compound sentiment
# 0  {'neg': 0.146, 'neu': 0.505, 'pos': 0.35, 'com...    0.7957       pos
# 1  {'neg': 0.0, 'neu': 0.661, 'pos': 0.339, 'comp...    0.6249       pos
# 2  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2023       pos
# 3  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.5719       pos
# 4  {'neg': 0.0, 'neu': 0.825, 'pos': 0.175, 'comp...    0.5267       pos

# %%
df.drop(['Unnamed: 0', 'language_scores', 'language', 'scores'], axis = 1, inplace = True)

# %%
df
# Out:
#             date                                             review  rating  \
# 0     2021-03-11  Interesting and clear, the difficulty in the e...       4
# 1     2021-03-11  great, i have learned basics of python from th...       5
# 2     2021-03-10                                        Recommended       5
# 3     2021-03-10                                          excellent       5
# 4     2021-03-10  Tamada sir is my biggest inspiration to comple...       5
# ...          ...                                                ...     ...
# 3111  2018-08-08  Good overall if you already have a grasp of py...       3
# 3112  2018-08-06                           good introductory course       5
# 3113  2018-08-03                                   robotic teaching       2
# 3114  2018-08-03                                       I recommend!       5
# 3115  2018-08-01  A great start in how to use python to access y...       5
#
#          status  length label  compound sentiment
# 0     completer     186   pos    0.7957       pos
# 1     completer      56   pos    0.6249       pos
# 2     completer      11   pos    0.2023       pos
# 3     completer       9   pos    0.5719       pos
# 4     completer     102   pos    0.5267       pos
# ...         ...     ...   ...       ...       ...
# 3111    dropout     135   neu    0.1027       pos
# 3112    dropout      24   pos    0.4404       pos
# 3113    dropout      16   neg    0.0000       neu
# 3114    dropout      12   pos    0.4199       pos
# 3115    dropout      55   pos    0.6588       pos
#
# [3116 rows x 8 columns]

# %%
# Check for null values

len(df[df['review'].isna()==True])
# Out:
# 0

# %%
# Drop null values

# df.dropna(inplace = True)

# %%
# Check for null values

# len(df[df['review'].isna()==True])

# %%
# Reset the index

# df = df.reset_index(drop = True)

# %%
# df

# %%
# Define a function to plot the most frequent words

def freq_words(x, terms = 30):
    all_words = ' '.join([text for text in x])
    all_words = all_words.split()

    fdist = FreqDist(all_words)
    words_df = pd.DataFrame({'word':list(fdist.keys()), 'count':list(fdist.values())})
    
    # selecting top 20 most frequent words
    d = words_df.nlargest(columns="count", n = terms) 
    plt.figure(figsize=(20,5))
    ax = sns.barplot(data = d, x = "word", y = "count")
    ax.set(ylabel = 'Count')
    plt.xticks(rotation = 45)
    plt.show()

# %%
# The most frquent words are stop words such as 'to' and 'the' we will remove these in the preprocessing steps

freq_words(df['review'])

# %% [markdown]
# ## Preprocessing

# %%
# Covert to lowercase

df['preprocessed'] =  df['review'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df['preprocessed'].head()
# Out:
# 0    interesting and clear, the difficulty in the e...
# 1    great, i have learned basics of python from th...
# 2                                          recommended
# 3                                            excellent
# 4    tamada sir is my biggest inspiration to comple...
# Name: preprocessed, dtype: object

# %%
# Remove punctuations

df['preprocessed'] = df['preprocessed'].str.replace('[^\w\s]','')
df['preprocessed'].head()
# Out:
# 0    interesting and clear the difficulty in the ex...
# 1    great i have learned basics of python from thi...
# 2                                          recommended
# 3                                            excellent
# 4    tamada sir is my biggest inspiration to comple...
# Name: preprocessed, dtype: object

# %%
# Remove stopwords

stop = stopwords.words('english')
stop.extend(['good', 'great', 'really', 'like', 'nice', 'bit'])

df['preprocessed'] = df['preprocessed'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df['preprocessed'].head(20)
# Out:
# 0     interesting clear difficulty exercises escalat...
# 1                          learned basics python course
# 2                                           recommended
# 3                                             excellent
# 4     tamada sir biggest inspiration complete course...
# 5                                         easy learning
# 6                                    python class thank
# 7     beginner python course covered lot understand ...
# 8     excellent class overview python starts basics ...
# 9     course goes informational video lab explaining...
# 10    class goes fast week 5 particularly challengin...
# 11
# 12                               awesome learn platform
# 13                                   perfectthanks much
# 14                                            many quiz
# 15                               course expected course
# 16                    syllabus acquired many new skills
# 17    poor quality videos basically sequence slides ...
# 18              well planned course animation excellent
# 19    valuable course learned python skillset contai...
# Name: preprocessed, dtype: object

# %%
# Remove short words (length < 3)

# df['review'] = df['review'].apply(lambda x: ' '.join([w for w in x.split() if len(w)>2]))
# df['review'].head()

# %%
df[(df['preprocessed']== "")]
# Out:
#             date       review  rating     status  length label  compound  \
# 11    2021-03-08  Good for me       5  completer      11   pos    0.4404
# 33    2021-03-02        Good        4  completer       5   pos    0.4404
# 45    2021-02-28         good       5  completer       4   pos    0.4404
# 74    2021-02-13        great       3  completer       5   neu    0.6249
# 207   2020-12-03        good.       2  completer       5   neg    0.4404
# ...          ...          ...     ...        ...     ...   ...       ...
# 2946  2019-01-01         Good       4  completer       4   pos    0.4404
# 2947  2018-12-31        Great       5  completer       5   pos    0.6249
# 2956  2018-12-26   it is good       3  completer      10   neu    0.4404
# 3046  2018-10-17    Very nice       5  completer       9   pos    0.4754
# 3067  2018-09-26    Good! :)        5  completer       9   pos    0.7345
#
#      sentiment preprocessed
# 11         pos
# 33         pos
# 45         pos
# 74         pos
# 207        pos
# ...        ...          ...
# 2946       pos
# 2947       pos
# 2956       pos
# 3046       pos
# 3067       pos
#
# [93 rows x 9 columns]

# %%
df = df[(df['preprocessed']!= "")]

# %%
# Reset the index

df = df.reset_index(drop = True)

# %%
# Look at the most frequent words again 

freq_words(df['preprocessed'])

# %%
# Tokenization

tokenizer = RegexpTokenizer(r'\w+')

df['preprocessed'] = df['preprocessed'].apply(lambda x: tokenizer.tokenize(x.lower()))
df['preprocessed'].head(5)
# Out:
# 0    [interesting, clear, difficulty, exercises, es...
# 1                    [learned, basics, python, course]
# 2                                        [recommended]
# 3                                          [excellent]
# 4    [tamada, sir, biggest, inspiration, complete, ...
# Name: preprocessed, dtype: object

# %%
# Add speech tags

df['preprocessed'] = df['preprocessed'].apply(nltk.tag.pos_tag)
df['preprocessed'].head()
# Out:
# 0    [(interesting, VBG), (clear, JJ), (difficulty,...
# 1    [(learned, VBN), (basics, NNS), (python, VBP),...
# 2                                 [(recommended, VBN)]
# 3                                    [(excellent, NN)]
# 4    [(tamada, NN), (sir, NN), (biggest, JJS), (ins...
# Name: preprocessed, dtype: object

# %%
# Define function to convert parts of speech tags to wordnet’s format

def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
# Apply the function to the tagged data

df['preprocessed'] = df['preprocessed'].apply(lambda x: [(word, get_wordnet_pos(pos_tag)) for (word, pos_tag) in x])
df['preprocessed'].head()
# Out:
# 0    [(interesting, v), (clear, a), (difficulty, n)...
# 1    [(learned, v), (basics, n), (python, v), (cour...
# 2                                   [(recommended, v)]
# 3                                     [(excellent, n)]
# 4    [(tamada, n), (sir, n), (biggest, a), (inspira...
# Name: preprocessed, dtype: object

# %%
df['preprocessed'][1]
# Out:
# [('learned', 'v'), ('basics', 'n'), ('python', 'v'), ('course', 'n')]

# %%
# Create lemmatizer

lemmatizer = WordNetLemmatizer()

# Apply to data 

df['preprocessed'] = df['preprocessed'].apply(lambda x: [lemmatizer.lemmatize(word, tag) for word, tag in x])
df['preprocessed'].head(8)
# Out:
# 0    [interest, clear, difficulty, exercise, escala...
# 1                       [learn, basic, python, course]
# 2                                          [recommend]
# 3                                          [excellent]
# 4    [tamada, sir, big, inspiration, complete, cour...
# 5                                     [easy, learning]
# 6                               [python, class, thank]
# 7    [beginner, python, course, cover, lot, underst...
# Name: preprocessed, dtype: object

# %%
# Join reviews

df['joined'] = df['preprocessed'].apply(lambda x: ' '.join(x))

# %%
# Most frequent words after lemmatizing 

freq_words(df['joined'], 35)

# %% [markdown]
# ## LDA Topic Modeling

# %%
# Create a dictionary from 'df_sen['review']' containing the number of times a word appears in the training set

dictionary = gensim.corpora.Dictionary(df['preprocessed'])

# %%
# Gensim filter extremes

# Filter out tokens that appear in:
# Less than 50 documents, more than 0.5 documents, and keep only 100000 most frquent tokens

# dictionary.filter_extremes(no_below = 50, no_above = 0.5, keep_n = 100000)

# %%
# Gensim doc2bow
# Create a dictionary reporting how many words and how many times those words appear

corpus = [dictionary.doc2bow(doc) for doc in df['preprocessed']]

# %%
corpus[1]
# Out:
# [(3, 1), (13, 1), (14, 1), (15, 1)]

# %%
# Add TF-IDF

tfidf = models.TfidfModel(corpus)      # Create a TF-IDF model
corpus_tfidf = tfidf[corpus]

# %%
# Creating the object for LDA model using gensim library
LDA = gensim.models.LdaMulticore

# Build LDA model
lda_model = LDA(corpus = corpus, id2word = dictionary, num_topics = 3, random_state = 100,
                chunksize = 100, passes = 10, alpha = 0.3)

# %%
# Explore the words occurring in each topic and its relative weight

for id, topic in lda_model.print_topics(-1):
    print('Topic: {}\nWord: {}\n'.format(id, topic))
    
print('Topic 0: Content, Topic 1: Course delivery, Topic 2: Course provider')
# Out:
# Topic: 0
# Word: 0.096*"course" + 0.064*"python" + 0.030*"data" + 0.026*"learn" + 0.024*"basic" + 0.021*"science" + 0.017*"beginner" + 0.012*"excellent" + 0.010*"well" + 0.010*"start"
#
# Topic: 1
# Word: 0.040*"course" + 0.024*"assignment" + 0.021*"final" + 0.013*"would" + 0.012*"project" + 0.010*"material" + 0.009*"time" + 0.008*"video" + 0.008*"week" + 0.008*"use"
#
# Topic: 2
# Word: 0.021*"content" + 0.020*"course" + 0.012*"ibm" + 0.011*"lab" + 0.009*"easy" + 0.008*"video" + 0.008*"need" + 0.008*"assignment" + 0.008*"quiz" + 0.007*"many"
#
# Topic 0: Content, Topic 1: Course delivery, Topic 2: Course provider

# %% [markdown]
# ### Visualise with pyLDAvis
#
# Original paper: https://nlp.stanford.edu/events/illvi2014/papers/sievert-illvi2014.pdf

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 0     -0.169808  0.031796       1        1  40.647190
# 1      0.041618 -0.109447       2        1  40.544935
# 2      0.128191  0.077651       3        1  18.807874, topic_info=           Term        Freq       Total Category  logprob  loglift
# 15       python  987.000000  987.000000  Default  30.0000  30.0000
# 99         data  419.000000  419.000000  Default  29.0000  29.0000
# 107     science  291.000000  291.000000  Default  28.0000  28.0000
# 13        basic  343.000000  343.000000  Default  27.0000  27.0000
# 187     content  169.000000  169.000000  Default  26.0000  26.0000
# ..          ...         ...         ...      ...      ...      ...
# 237         use   34.953535  242.457426   Topic3  -5.2036  -0.2659
# 24         make   30.758152  162.003717   Topic3  -5.3315   0.0094
# 93   understand   28.368312  157.224552   Topic3  -5.4123  -0.0415
# 132       final   31.518472  323.278524   Topic3  -5.3070  -0.6570
# 318       could   27.619067  151.397466   Topic3  -5.4391  -0.0305
#
# [234 rows x 6 columns], token_table=      Topic      Freq   Term
# term
# 2475      1  0.969871    101
# 361       1  0.025221      4
# 361       2  0.958395      4
# 361       3  0.025221      4
# 162       2  0.861954      5
# ...     ...       ...    ...
# 353       2  0.571971   work
# 353       3  0.236678   work
# 96        1  0.203750  would
# 96        2  0.691153  would
# 96        3  0.103873  would
#
# [382 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[1, 2, 3])

# %% [markdown]
# What is topic perplexity and topic coherence: https://towardsdatascience.com/evaluate-topic-model-in-python-latent-dirichlet-allocation-lda-7d57484bb5d0

# %%
# Calculate Perplexity and Coherence

# Compute Perplexity

print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. The lower the better.

# Compute Coherence Score

coherence_model_lda = CoherenceModel(model = lda_model, texts = df['preprocessed'], dictionary = dictionary, coherence = 'c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Perplexity:  -6.7499581153092745
#
# Coherence Score:  0.5980720918475521

# %% [markdown]
# ## Hyperparameter Tuning
#
# Code references
#
# Find the optimal number of topics, alpha and beta: https://towardsdatascience.com/evaluate-topic-model-in-python-latent-dirichlet-allocation-lda-7d57484bb5d0
#
# What is alpha and beta: https://www.thoughtvector.io/blog/lda-alpha-and-beta-parameters-the-intuition/

# %% [markdown]
# ## Calculate the coherence score
#
# Code reference:
#
# https://www.machinelearningplus.com/nlp/topic-modeling-gensim-python/#17howtofindtheoptimalnumberoftopicsforlda

# %%
# Determine the optiomal number of topics by calculating the coherence score

# Define function for calculating coherence score

def compute_coherence_values(dictionary, corpus, texts, limit, start = 2, step = 3):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = LDA(corpus = corpus, num_topics = num_topics, id2word = dictionary, random_state = 100,
                chunksize = 100, passes = 10, alpha = 0.3)
        model_list.append(model)
        coherencemodel = CoherenceModel(model = model, texts = texts, dictionary = dictionary, coherence = 'c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values

# %%
# Can take a long time to run.

model_list, coherence_values = compute_coherence_values(dictionary = dictionary, corpus = corpus, texts = df['preprocessed'], start = 2, limit = 10, step = 1)

# %%
# Show graph

limit = 10; start = 2; step = 1;
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc = 'best')
plt.show()

# %%
# Print the coherence scores

for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4))
# Out:
# Num Topics = 2  has Coherence Value of 0.5482
# Num Topics = 3  has Coherence Value of 0.58
# Num Topics = 4  has Coherence Value of 0.5381
# Num Topics = 5  has Coherence Value of 0.5243
# Num Topics = 6  has Coherence Value of 0.5245
# Num Topics = 7  has Coherence Value of 0.5326
# Num Topics = 8  has Coherence Value of 0.4994
# Num Topics = 9  has Coherence Value of 0.5219

# %% [markdown]
# ## LDA Mallet Model
#
# Code reference:
#
# https://www.machinelearningplus.com/nlp/topic-modeling-gensim-python/#17howtofindtheoptimalnumberoftopicsforlda

# %%
mallet_path = '/Users/siriamanda/Desktop/LNU-VT-2021/Thesis/11-data-analysis/mallet-2.0.8/bin/mallet' # update this path
ldamallet = gensim.models.wrappers.LdaMallet(mallet_path, corpus = corpus, num_topics = 5, id2word = dictionary)

# %%
# Show Topics
pprint(ldamallet.show_topics(formatted = False))

# Compute Coherence Score
coherence_model_ldamallet = CoherenceModel(model = ldamallet, texts = df['preprocessed'], dictionary = dictionary, coherence = 'c_v')
coherence_ldamallet = coherence_model_ldamallet.get_coherence()
print('\nCoherence Score: ', coherence_ldamallet)

# The coherence score using the Mallet Model is lower than the original LDA Model
# Out:
# [(0,
#   [('learn', 0.10453528574333944),
#    ('ibm', 0.06589383770591824),
#    ('lot', 0.04820012202562538),
#    ('give', 0.03355704697986577),
#    ('watson', 0.030913158429936954),
#    ('experience', 0.028269269880008135),
#    ('helpful', 0.0278625177954037),
#    ('coursera', 0.023388244864754933),
#    ('thing', 0.021964612568639415),
#    ('teach', 0.01972747610331503)]),
#  (1,
#   [('easy', 0.04548959136468774),
#    ('understand', 0.03508095605242868),
#    ('make', 0.034309946029298384),
#    ('week', 0.025443330763299923),
#    ('complete', 0.02120277563608327),
#    ('find', 0.019468003084040092),
#    ('explanation', 0.017733230531996914),
#    ('material', 0.01754047802621434),
#    ('question', 0.01638396299151889),
#    ('information', 0.015034695451040863)]),
#  (2,
#   [('assignment', 0.06472369417108251),
#    ('final', 0.053747161241483724),
#    ('work', 0.029901589704769114),
#    ('project', 0.027819833459500377),
#    ('instruction', 0.02668433005299016),
#    ('time', 0.023088569265707796),
#    ('cloud', 0.019114307342922028),
#    ('material', 0.014950794852384557),
#    ('class', 0.014193792581377745),
#    ('challenge', 0.013626040878122634)]),
#  (3,
#   [('beginner', 0.06719447827852212),
#    ('video', 0.0389768574908648),
#    ('exercise', 0.030450669914738125),
#    ('content', 0.030044660982541615),
#    ('explain', 0.028420625253755584),
#    ('concept', 0.028217620787657327),
#    ('lab', 0.027608607389362567),
#    ('practice', 0.02476654486398701),
#    ('clear', 0.021721477872513197),
#    ('labs', 0.021112464474218433)]),
#  (4,
#   [('python', 0.19625438938743658),
#    ('data', 0.09851736246586032),
#    ('basic', 0.07335154116269996),
#    ('science', 0.06652360515021459),
#    ('start', 0.03589543503706594),
#    ('excellent', 0.03492001560671089),
#    ('program', 0.02848224736636754),
#    ('knowledge', 0.02633632461958642),
#    ('introduction', 0.024385485758876318),
#    ('ai', 0.015606710885680842)])]
#
# Coherence Score:  0.472949346984462

# %%
# Create new column with the topic

df['topic'] = ''

df['topic'] = [max(p, key = lambda item: item[1]) for p in lda_model[corpus]]

# %%
# Create two separate columns for the topic ID and topic score

df[['topic_id', 'topic_score']] = df['topic'].apply(pd.Series)

# %%
df
# Out:
#             date                                             review  rating  \
# 0     2021-03-11  Interesting and clear, the difficulty in the e...       4
# 1     2021-03-11  great, i have learned basics of python from th...       5
# 2     2021-03-10                                        Recommended       5
# 3     2021-03-10                                          excellent       5
# 4     2021-03-10  Tamada sir is my biggest inspiration to comple...       5
# ...          ...                                                ...     ...
# 3018  2018-08-08  Good overall if you already have a grasp of py...       3
# 3019  2018-08-06                           good introductory course       5
# 3020  2018-08-03                                   robotic teaching       2
# 3021  2018-08-03                                       I recommend!       5
# 3022  2018-08-01  A great start in how to use python to access y...       5
#
#          status  length label  compound sentiment  \
# 0     completer     186   pos    0.7957       pos
# 1     completer      56   pos    0.6249       pos
# 2     completer      11   pos    0.2023       pos
# 3     completer       9   pos    0.5719       pos
# 4     completer     102   pos    0.5267       pos
# ...         ...     ...   ...       ...       ...
# 3018    dropout     135   neu    0.1027       pos
# 3019    dropout      24   pos    0.4404       pos
# 3020    dropout      16   neg    0.0000       neu
# 3021    dropout      12   pos    0.4199       pos
# 3022    dropout      55   pos    0.6588       pos
#
#                                            preprocessed  \
# 0     [interest, clear, difficulty, exercise, escala...
# 1                        [learn, basic, python, course]
# 2                                           [recommend]
# 3                                           [excellent]
# 4     [tamada, sir, big, inspiration, complete, cour...
# ...                                                 ...
# 3018  [overall, already, grasp, python, lot, mistake...
# 3019                             [introductory, course]
# 3020                                [robotic, teaching]
# 3021                                        [recommend]
# 3022                 [start, use, python, access, data]
#
#                                                  joined            topic  \
# 0     interest clear difficulty exercise escalate pr...   (0, 0.7999046)
# 1                             learn basic python course  (0, 0.87557936)
# 2                                             recommend  (0, 0.67394125)
# 3                                             excellent   (0, 0.6836881)
# 4     tamada sir big inspiration complete courseinsp...   (2, 0.7478987)
# ...                                                 ...              ...
# 3018  overall already grasp python lot mistake coher...  (2, 0.47517183)
# 3019                                introductory course    (0, 0.788395)
# 3020                                   robotic teaching   (2, 0.7907945)
# 3021                                          recommend   (0, 0.6739331)
# 3022                       start use python access data   (0, 0.6982174)
#
#       topic_id  topic_score
# 0          0.0     0.799905
# 1          0.0     0.875579
# 2          0.0     0.673941
# 3          0.0     0.683688
# 4          2.0     0.747899
# ...        ...          ...
# 3018       2.0     0.475172
# 3019       0.0     0.788395
# 3020       2.0     0.790794
# 3021       0.0     0.673933
# 3022       0.0     0.698217
#
# [3023 rows x 13 columns]

# %% [markdown]
# ## Evaluation

# %%
df.loc[df['topic_id'] == 0.0]
# Out:
#             date                                             review  rating  \
# 0     2021-03-11  Interesting and clear, the difficulty in the e...       4
# 1     2021-03-11  great, i have learned basics of python from th...       5
# 2     2021-03-10                                        Recommended       5
# 3     2021-03-10                                          excellent       5
# 5     2021-03-10                             good and easy learning       3
# ...          ...                                                ...     ...
# 3015  2018-08-15                                 Great fundamentals       5
# 3017  2018-08-14               Thank you very much cousera and IBM.       5
# 3019  2018-08-06                           good introductory course       5
# 3021  2018-08-03                                       I recommend!       5
# 3022  2018-08-01  A great start in how to use python to access y...       5
#
#          status  length label  compound sentiment  \
# 0     completer     186   pos    0.7957       pos
# 1     completer      56   pos    0.6249       pos
# 2     completer      11   pos    0.2023       pos
# 3     completer       9   pos    0.5719       pos
# 5     completer      22   neu    0.7003       pos
# ...         ...     ...   ...       ...       ...
# 3015    dropout      18   pos    0.6249       pos
# 3017    dropout      36   pos    0.3612       pos
# 3019    dropout      24   pos    0.4404       pos
# 3021    dropout      12   pos    0.4199       pos
# 3022    dropout      55   pos    0.6588       pos
#
#                                            preprocessed  \
# 0     [interest, clear, difficulty, exercise, escala...
# 1                        [learn, basic, python, course]
# 2                                           [recommend]
# 3                                           [excellent]
# 5                                      [easy, learning]
# ...                                                 ...
# 3015                                      [fundamental]
# 3017                        [thank, much, cousera, ibm]
# 3019                             [introductory, course]
# 3021                                        [recommend]
# 3022                 [start, use, python, access, data]
#
#                                                  joined            topic  \
# 0     interest clear difficulty exercise escalate pr...   (0, 0.7999046)
# 1                             learn basic python course  (0, 0.87557936)
# 2                                             recommend  (0, 0.67394125)
# 3                                             excellent   (0, 0.6836881)
# 5                                         easy learning   (0, 0.7703181)
# ...                                                 ...              ...
# 3015                                        fundamental   (0, 0.6781362)
# 3017                             thank much cousera ibm   (0, 0.8631796)
# 3019                                introductory course    (0, 0.788395)
# 3021                                          recommend   (0, 0.6739331)
# 3022                       start use python access data   (0, 0.6982174)
#
#       topic_id  topic_score
# 0          0.0     0.799905
# 1          0.0     0.875579
# 2          0.0     0.673941
# 3          0.0     0.683688
# 5          0.0     0.770318
# ...        ...          ...
# 3015       0.0     0.678136
# 3017       0.0     0.863180
# 3019       0.0     0.788395
# 3021       0.0     0.673933
# 3022       0.0     0.698217
#
# [1744 rows x 13 columns]

# %%
df.loc[df['topic_id'] == 1.0]
# Out:
#             date                                             review  rating  \
# 10    2021-03-09  The class goes too fast. Week 5 was particular...       3
# 12    2021-03-08                      perfect.Thanks you very much        5
# 24    2021-03-05  Quiz questions sometimes pop-up before the sub...       3
# 25    2021-03-04  Let's be honest, no one without any experience...       2
# 27    2021-03-04  Some modules seemed disjointed and this shows ...       4
# ...          ...                                                ...     ...
# 2997  2018-09-07  the material and movies were good, response fr...       3
# 3002  2018-08-31       No support from moderators, plenty of typos.       1
# 3007  2018-08-24  Great course, perfect in explaining Python. Sm...       4
# 3011  2018-08-20                         Final Assignment quite con       5
# 3014  2018-08-16  Very basic introduction, but clear enough for ...       4
#
#          status  length label  compound sentiment  \
# 10    completer     126   neu    0.2247       pos
# 12    completer      29   pos    0.0000       neu
# 24    completer     139   neu    0.0000       neu
# 25      dropout     978   neg    0.8414       pos
# 27    completer     488   pos   -0.3612       neg
# ...         ...     ...   ...       ...       ...
# 2997    dropout     273   neu   -0.3400       neg
# 3002  completer      44   neg    0.1280       pos
# 3007    dropout      89   pos    0.8316       pos
# 3011    dropout      26   pos    0.0000       neu
# 3014    dropout      98   pos    0.6124       pos
#
#                                            preprocessed  \
# 10    [class, go, fast, week, 5, particularly, chall...
# 12                                [perfectthanks, much]
# 24    [quiz, question, sometimes, popup, subject, ma...
# 25    [let, honest, one, without, experience, progra...
# 27    [module, seem, disjointed, show, lab, session,...
# ...                                                 ...
# 2997  [material, movie, response, teacher, question,...
# 3002                 [support, moderator, plenty, typo]
# 3007  [course, perfect, explain, python, small, issu...
# 3011                    [final, assignment, quite, con]
# 3014  [basic, introduction, clear, enough, beginner,...
#
#                                                  joined            topic  \
# 10    class go fast week 5 particularly challenging ...    (1, 0.906125)
# 12                                   perfectthanks much  (1, 0.77228904)
# 24    quiz question sometimes popup subject material...   (1, 0.9561695)
# 25    let honest one without experience programming ...   (1, 0.5665765)
# 27    module seem disjointed show lab session diffic...   (1, 0.6851488)
# ...                                                 ...              ...
# 2997  material movie response teacher question terri...   (1, 0.9757555)
# 3002                      support moderator plenty typo   (1, 0.8664161)
# 3007  course perfect explain python small issue subm...   (1, 0.5641982)
# 3011                         final assignment quite con  (1, 0.67692435)
# 3014  basic introduction clear enough beginner final...  (1, 0.59234446)
#
#       topic_id  topic_score
# 10         1.0     0.906125
# 12         1.0     0.772289
# 24         1.0     0.956169
# 25         1.0     0.566576
# 27         1.0     0.685149
# ...        ...          ...
# 2997       1.0     0.975756
# 3002       1.0     0.866416
# 3007       1.0     0.564198
# 3011       1.0     0.676924
# 3014       1.0     0.592344
#
# [831 rows x 13 columns]

# %%
df.loc[df['topic_id'] == 2.0].tail(50)
# Out:
#             date                                             review  rating  \
# 2790  2019-02-07  Easy to follow. A good starter for those witho...       5
# 2796  2019-02-03  Assignment is definitely tricky, given the pre...       5
# 2804  2019-01-30  The course content is great but the peer revie...       3
# 2819  2019-01-22  Great environment CC - labs for learning pytho...       5
# 2835  2019-01-13  content is good but it should be more descriptive       4
# 2838  2019-01-12  The content is useful however there are quite ...       4
# 2841  2019-01-11                                      Good content.       5
# 2854  2019-01-03  It is amazing how bad this is considering that...       1
# 2857  2019-01-02  Course content and section quizzes are bit too...       4
# 2869  2018-12-23                    assignment are of good quality.       5
# 2872  2018-12-20  Good and quick run-through of essential python...       3
# 2873  2018-12-17  lacks rigor and the assignments were way tooo ...       1
# 2885  2018-12-08  The course contents are well organized. Topics...       4
# 2886  2018-12-07                                           too easy       2
# 2888  2018-12-06  This course does a good job of introducing the...       3
# 2889  2018-12-05  Ok course, but the videos had many errors that...       4
# 2890  2018-12-05                            Easy to mange and learn       5
# 2899  2018-11-28                               Simple and efficient       5
# 2901  2018-11-26  Still I don't understand the relation of the c...       1
# 2902  2018-11-25          Great programming content and explanation       5
# 2905  2018-11-23  The course material is ok (a bit to basic) but...       2
# 2916  2018-11-14  The final project at week 5 needs to be comple...       1
# 2921  2018-11-12  The course covers the content taught in a very...       2
# 2923  2018-11-11  Enjoyed the labs but the videos are too dull, ...       4
# 2925  2018-11-08  A must-course to register, for anyone who aspi...       5
# 2933  2018-11-05  There is some incorrect content and videos tha...       3
# 2937  2018-11-02  Very much interactive course. It was very well...       5
# 2940  2018-10-30            Very cool source. I love it very much.        5
# 2942  2018-10-30  The IBM cloud "service" leaves much to be desi...       1
# 2946  2018-10-28  Thumbs Up!Although when grading others work th...       5
# 2950  2018-10-24  Don't over complicate the course. You'll save ...       5
# 2958  2018-10-12  While the content itself was informative, ther...       3
# 2959  2018-10-12  I observed mistakes here and there, there are ...       3
# 2964  2018-10-10  Minimum of practice, don't need much effort to...       4
# 2969  2018-10-04  The course is kinda helpful. But please, stop ...       1
# 2971  2018-10-03  Thank you joshep santarcangelo and coursera.or...       5
# 2974  2018-09-28                                     Good Lectures.       5
# 2980  2018-09-19  The contents are arranged in the right sequenc...       5
# 2986  2018-09-17  Decent intro to python programming. The videos...       3
# 2988  2018-09-15  The python part is good but the pandas is outd...       3
# 2990  2018-09-14  I'mvery much impressed by the quality of the c...       5
# 2993  2018-09-11  Too many spelling mistakes in the notebooks, t...       3
# 2994  2018-09-09  This was a nice ramp up course that familiaris...       4
# 2995  2018-09-09  I had some programming knowledge (C++, matlab)...       3
# 3006  2018-08-27                                               cool       5
# 3012  2018-08-19  Fifth star will come whe you abandon peer grad...       4
# 3013  2018-08-18  This lectures and his contents is too helpful....       5
# 3016  2018-08-15              More practice exercises would be cool       4
# 3018  2018-08-08  Good overall if you already have a grasp of py...       3
# 3020  2018-08-03                                   robotic teaching       2
#
#          status  length label  compound sentiment  \
# 2790  completer      64   pos    0.7003       pos
# 2796  completer     134   pos    0.7717       pos
# 2804  completer     350   neu    0.5789       pos
# 2819  completer      85   pos    0.8481       pos
# 2835  completer      49   pos    0.2382       pos
# 2838    dropout      88   pos    0.0314       pos
# 2841  completer      13   pos    0.4404       pos
# 2854    dropout     551   neg   -0.2783       neg
# 2857  completer     160   pos    0.0000       neu
# 2869  completer      31   pos    0.4404       pos
# 2872  completer     217   neu   -0.4310       neg
# 2873  completer      70   neg    0.0000       neu
# 2885    dropout     178   pos   -0.1531       neg
# 2886  completer       8   neg    0.4404       pos
# 2888    dropout     284   neu   -0.5574       neg
# 2889  completer     103   pos    0.1154       pos
# 2890  completer      23   pos    0.4404       pos
# 2899  completer      20   pos    0.4215       pos
# 2901  completer     768   neg    0.7927       pos
# 2902  completer      41   pos    0.6249       pos
# 2905  completer     276   neg   -0.6750       neg
# 2916    dropout     171   neg   -0.7769       neg
# 2921    dropout     668   neg   -0.0372       neg
# 2923  completer     119   pos   -0.3400       neg
# 2925  completer     113   pos    0.4927       pos
# 2933    dropout      69   neu    0.0000       neu
# 2937  completer      97   pos    0.6478       pos
# 2940  completer      39   pos    0.7939       pos
# 2942  completer     447   neg    0.6586       pos
# 2946    dropout     143   pos    0.0000       neu
# 2950    dropout      69   pos    0.4939       pos
# 2958    dropout     117   neu   -0.6705       neg
# 2959  completer     198   neu   -0.2023       neg
# 2964  completer     156   pos    0.5859       pos
# 2969  completer     530   neg   -0.9511       neg
# 2971  completer     137   pos    0.9041       pos
# 2974  completer      14   pos    0.4404       pos
# 2980  completer     137   pos    0.0000       neu
# 2986  completer     143   neu    0.0000       neu
# 2988    dropout      92   neu    0.2382       pos
# 2990    dropout      53   pos    0.4767       pos
# 2993    dropout     248   neu   -0.5868       neg
# 2994  completer     159   pos    0.5994       pos
# 2995  completer     870   neu    0.9850       pos
# 3006  completer       4   pos    0.3182       pos
# 3012    dropout      98   pos   -0.7579       neg
# 3013    dropout      56   pos    0.0000       neu
# 3016    dropout      37   pos    0.3182       pos
# 3018    dropout     135   neu    0.1027       pos
# 3020    dropout      16   neg    0.0000       neu
#
#                                            preprocessed  \
# 2790  [easy, follow, starter, without, csie, backgroud]
# 2796  [assignment, definitely, tricky, give, preceed...
# 2804  [course, content, peer, review, exam, confuse,...
# 2819  [environment, cc, lab, learn, python, example,...
# 2835                             [content, descriptive]
# 2838  [content, useful, however, quite, mistakes, pr...
# 2841                                          [content]
# 2854  [amaze, bad, consider, marketed, ibm, product,...
# 2857  [course, content, section, quiz, simple, compa...
# 2869                              [assignment, quality]
# 2872  [quick, runthrough, essential, python, five, s...
# 2873  [lack, rigor, assignment, way, tooo, easy, thumb]
# 2885  [course, content, well, organize, topic, essen...
# 2886                                             [easy]
# 2888  [course, job, introduce, basic, python, howeve...
# 2889  [ok, course, videos, many, error, coincide, di...
# 2890                               [easy, mange, learn]
# 2899                                [simple, efficient]
# 2901  [still, dont, understand, relation, course, co...
# 2902                    [program, content, explanation]
# 2905  [course, material, ok, basic, personally, dont...
# 2916  [final, project, week, 5, need, completely, re...
# 2921  [course, cover, content, taught, superficial, ...
# 2923  [enjoy, labs, video, dull, ie, often, list, po...
# 2925  [mustcourse, register, anyone, aspire, become,...
# 2933        [incorrect, content, video, work, properly]
# 2937  [much, interactive, course, well, constructed,...
# 2940                         [cool, source, love, much]
# 2942  [ibm, cloud, service, leave, much, desire, mul...
# 2946  [thumb, upalthough, grade, others, work, aws, ...
# 2950  [dont, complicate, course, youll, save, headache]
# 2958  [content, informative, many, typoserrors, dist...
# 2959  [observed, mistake, proper, instruction, instr...
# 2964  [minimum, practice, dont, need, much, effort, ...
# 2969  [course, kinda, helpful, please, stop, use, pe...
# 2971  [thank, joshep, santarcangelo, courseraorg, su...
# 2974                                          [lecture]
# 2980  [content, arrange, right, sequence, start, pyt...
# 2986  [decent, intro, python, program, video, labs, ...
# 2988  [python, part, panda, outdated, dfix, instance...
# 2990        [imvery, much, impressed, quality, content]
# 2993  [many, spell, mistake, notebooks, many, error,...
# 2994  [ramp, course, familiarise, well, basic, howev...
# 2995  [program, knowledge, c, matlab, begin, course,...
# 3006                                             [cool]
# 3012  [fifth, star, come, whe, abandon, peer, grade,...
# 3013                   [lecture, content, helpfulthank]
# 3016                  [practice, exercise, would, cool]
# 3018  [overall, already, grasp, python, lot, mistake...
# 3020                                [robotic, teaching]
#
#                                                  joined            topic  \
# 2790         easy follow starter without csie backgroud   (2, 0.8903224)
# 2796  assignment definitely tricky give preceeding c...   (2, 0.8346677)
# 2804  course content peer review exam confuse bring ...   (2, 0.7685469)
# 2819  environment cc lab learn python example enjoed...  (2, 0.65401417)
# 2835                                content descriptive   (2, 0.7923109)
# 2838  content useful however quite mistakes presenta...   (2, 0.9153498)
# 2841                                            content  (2, 0.68198866)
# 2854  amaze bad consider marketed ibm product level ...   (2, 0.7476551)
# 2857  course content section quiz simple compare fin...   (2, 0.6667281)
# 2869                                 assignment quality   (2, 0.5589588)
# 2872  quick runthrough essential python five star ma...  (2, 0.96852237)
# 2873          lack rigor assignment way tooo easy thumb  (2, 0.91608137)
# 2885  course content well organize topic essential p...  (2, 0.67784303)
# 2886                                               easy   (2, 0.6445513)
# 2888  course job introduce basic python however slid...   (2, 0.8732566)
# 2889  ok course videos many error coincide dialog pl...  (2, 0.93470865)
# 2890                                   easy mange learn  (2, 0.51602226)
# 2899                                   simple efficient  (2, 0.77352226)
# 2901  still dont understand relation course content ...  (2, 0.69585186)
# 2902                        program content explanation  (2, 0.82197237)
# 2905  course material ok basic personally dont robot...  (2, 0.89740014)
# 2916  final project week 5 need completely revamp po...  (2, 0.79237634)
# 2921  course cover content taught superficial manner...  (2, 0.48407733)
# 2923  enjoy labs video dull ie often list possible c...   (2, 0.5320046)
# 2925  mustcourse register anyone aspire become data ...   (2, 0.4918573)
# 2933              incorrect content video work properly   (2, 0.8939066)
# 2937  much interactive course well constructed begin...   (2, 0.6468667)
# 2940                              cool source love much   (2, 0.8611741)
# 2942  ibm cloud service leave much desire multiple t...    (2, 0.935119)
# 2946  thumb upalthough grade others work aws launch ...   (2, 0.9534526)
# 2950         dont complicate course youll save headache  (2, 0.90417117)
# 2958  content informative many typoserrors distract ...  (2, 0.90939534)
# 2959  observed mistake proper instruction instructor...  (2, 0.96350485)
# 2964  minimum practice dont need much effort accompl...  (2, 0.96251595)
# 2969  course kinda helpful please stop use peerrevie...  (2, 0.98682606)
# 2971  thank joshep santarcangelo courseraorg support...  (2, 0.64546186)
# 2974                                            lecture   (2, 0.6747447)
# 2980  content arrange right sequence start python oc...   (2, 0.7531642)
# 2986  decent intro python program video labs need ad...   (2, 0.8865578)
# 2988  python part panda outdated dfix instance depre...  (2, 0.73177904)
# 2990              imvery much impressed quality content   (2, 0.8956292)
# 2993  many spell mistake notebooks many error slide ...   (2, 0.9743892)
# 2994  ramp course familiarise well basic however fel...   (2, 0.8414135)
# 2995  program knowledge c matlab begin course easy c...   (2, 0.9841062)
# 3006                                               cool   (2, 0.6841071)
# 3012  fifth star come whe abandon peer grade system ...   (2, 0.6186499)
# 3013                       lecture content helpfulthank  (2, 0.84431994)
# 3016                       practice exercise would cool   (2, 0.8507601)
# 3018  overall already grasp python lot mistake coher...  (2, 0.47517183)
# 3020                                   robotic teaching   (2, 0.7907945)
#
#       topic_id  topic_score
# 2790       2.0     0.890322
# 2796       2.0     0.834668
# 2804       2.0     0.768547
# 2819       2.0     0.654014
# 2835       2.0     0.792311
# 2838       2.0     0.915350
# 2841       2.0     0.681989
# 2854       2.0     0.747655
# 2857       2.0     0.666728
# 2869       2.0     0.558959
# 2872       2.0     0.968522
# 2873       2.0     0.916081
# 2885       2.0     0.677843
# 2886       2.0     0.644551
# 2888       2.0     0.873257
# 2889       2.0     0.934709
# 2890       2.0     0.516022
# 2899       2.0     0.773522
# 2901       2.0     0.695852
# 2902       2.0     0.821972
# 2905       2.0     0.897400
# 2916       2.0     0.792376
# 2921       2.0     0.484077
# 2923       2.0     0.532005
# 2925       2.0     0.491857
# 2933       2.0     0.893907
# 2937       2.0     0.646867
# 2940       2.0     0.861174
# 2942       2.0     0.935119
# 2946       2.0     0.953453
# 2950       2.0     0.904171
# 2958       2.0     0.909395
# 2959       2.0     0.963505
# 2964       2.0     0.962516
# 2969       2.0     0.986826
# 2971       2.0     0.645462
# 2974       2.0     0.674745
# 2980       2.0     0.753164
# 2986       2.0     0.886558
# 2988       2.0     0.731779
# 2990       2.0     0.895629
# 2993       2.0     0.974389
# 2994       2.0     0.841413
# 2995       2.0     0.984106
# 3006       2.0     0.684107
# 3012       2.0     0.618650
# 3013       2.0     0.844320
# 3016       2.0     0.850760
# 3018       2.0     0.475172
# 3020       2.0     0.790794

# %%
df_final = df.drop(['joined', 'topic'], axis = 1)

# %%
df_final
# Out:
#             date                                             review  rating  \
# 0     2021-03-11  Interesting and clear, the difficulty in the e...       4
# 1     2021-03-11  great, i have learned basics of python from th...       5
# 2     2021-03-10                                        Recommended       5
# 3     2021-03-10                                          excellent       5
# 4     2021-03-10  Tamada sir is my biggest inspiration to comple...       5
# ...          ...                                                ...     ...
# 3018  2018-08-08  Good overall if you already have a grasp of py...       3
# 3019  2018-08-06                           good introductory course       5
# 3020  2018-08-03                                   robotic teaching       2
# 3021  2018-08-03                                       I recommend!       5
# 3022  2018-08-01  A great start in how to use python to access y...       5
#
#          status  length label  compound sentiment  \
# 0     completer     186   pos    0.7957       pos
# 1     completer      56   pos    0.6249       pos
# 2     completer      11   pos    0.2023       pos
# 3     completer       9   pos    0.5719       pos
# 4     completer     102   pos    0.5267       pos
# ...         ...     ...   ...       ...       ...
# 3018    dropout     135   neu    0.1027       pos
# 3019    dropout      24   pos    0.4404       pos
# 3020    dropout      16   neg    0.0000       neu
# 3021    dropout      12   pos    0.4199       pos
# 3022    dropout      55   pos    0.6588       pos
#
#                                            preprocessed  topic_id  topic_score
# 0     [interest, clear, difficulty, exercise, escala...       0.0     0.799905
# 1                        [learn, basic, python, course]       0.0     0.875579
# 2                                           [recommend]       0.0     0.673941
# 3                                           [excellent]       0.0     0.683688
# 4     [tamada, sir, big, inspiration, complete, cour...       2.0     0.747899
# ...                                                 ...       ...          ...
# 3018  [overall, already, grasp, python, lot, mistake...       2.0     0.475172
# 3019                             [introductory, course]       0.0     0.788395
# 3020                                [robotic, teaching]       2.0     0.790794
# 3021                                        [recommend]       0.0     0.673933
# 3022                 [start, use, python, access, data]       0.0     0.698217
#
# [3023 rows x 11 columns]

# %%
# Save dataframe as a csv file

df_final.to_csv('python-for-data-final.csv')
